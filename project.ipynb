# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/ozone_layer_classification.csv")
df.head()
# Out:
#    Year   Latitude   Longitude  Avg_Temp_C  UV_Index     CFC_ppb     CO2_ppm  \
# 0  2018  29.735500    9.734927   15.104432 -0.813976  254.305543  410.362034
# 1  2008   4.151776  -26.609982   16.153505  4.250356  212.653836  389.415980
# 2  1994 -25.410513 -132.944264    8.699176  2.922912  299.508312  382.614260
# 3  2022  67.896097  139.177517   11.918193  1.737448  239.143446  399.782657
# 4  1987 -19.359881  -18.077526   13.124018  2.525147  276.326834  402.747050
#
#    Methane_ppb     N2O_ppb Ozone_Status
# 0  1722.697029  312.466058       Stable
# 1  1712.927223  343.209199       Stable
# 2  1872.459178  322.290135       Stable
# 3  1844.848545  288.572456       Stable
# 4  1784.146231  353.354839       Stable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          1000 non-null   int64
#  1   Latitude      1000 non-null   float64
#  2   Longitude     1000 non-null   float64
#  3   Avg_Temp_C    1000 non-null   float64
#  4   UV_Index      1000 non-null   float64
#  5   CFC_ppb       1000 non-null   float64
#  6   CO2_ppm       1000 non-null   float64
#  7   Methane_ppb   1000 non-null   float64
#  8   N2O_ppb       1000 non-null   float64
#  9   Ozone_Status  1000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#               Year     Latitude    Longitude   Avg_Temp_C     UV_Index  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   2002.000000     0.479191    -1.259691    15.017804     4.980092
# std      12.945562    52.487714   103.290401     4.931054     2.052765
# min    1980.000000   -89.166236  -179.951511     0.044320    -0.858897
# 25%    1991.000000   -47.242093   -86.308347    11.752645     3.528660
# 50%    2003.000000     2.475528    -1.678752    14.984238     5.002971
# 75%    2013.000000    44.951218    89.136576    18.256163     6.359455
# max    2024.000000    89.894471   179.405104    34.631189    11.486186
#
#            CFC_ppb      CO2_ppm  Methane_ppb      N2O_ppb
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean    248.186589   399.158836  1796.011282   330.041902
# std      49.468314    20.211363   103.960081    20.689230
# min      91.164809   342.009722  1477.898364   256.232694
# 25%     216.291407   385.506820  1724.823625   315.907721
# 50%     249.894135   399.088169  1794.525362   329.415191
# 75%     282.379059   412.529212  1869.974508   344.160932
# max     405.645510   461.965989  2152.905519   392.353623

# %%
df.isnull().sum()
# Out:
# Year            0
# Latitude        0
# Longitude       0
# Avg_Temp_C      0
# UV_Index        0
# CFC_ppb         0
# CO2_ppm         0
# Methane_ppb     0
# N2O_ppb         0
# Ozone_Status    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Ozone_Status'] = label_encoder.fit_transform(df['Ozone_Status'])

# %%
df.head()
# Out:
#    Year   Latitude   Longitude  Avg_Temp_C  UV_Index     CFC_ppb     CO2_ppm  \
# 0  2018  29.735500    9.734927   15.104432 -0.813976  254.305543  410.362034
# 1  2008   4.151776  -26.609982   16.153505  4.250356  212.653836  389.415980
# 2  1994 -25.410513 -132.944264    8.699176  2.922912  299.508312  382.614260
# 3  2022  67.896097  139.177517   11.918193  1.737448  239.143446  399.782657
# 4  1987 -19.359881  -18.077526   13.124018  2.525147  276.326834  402.747050
#
#    Methane_ppb     N2O_ppb  Ozone_Status
# 0  1722.697029  312.466058             1
# 1  1712.927223  343.209199             1
# 2  1872.459178  322.290135             1
# 3  1844.848545  288.572456             1
# 4  1784.146231  353.354839             1

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Ozone_Status"])
y = df["Ozone_Status"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(ytest, ypred)
class_report = classification_report(ytest, ypred)

# Print results
print("Model Accuracy:", accuracy)
print("Classification Report:\n", class_report)
# Out:
# Model Accuracy: 0.975
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.97      1.00      0.99       195
#
#     accuracy                           0.97       200
#    macro avg       0.49      0.50      0.49       200
# weighted avg       0.95      0.97      0.96       200
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
